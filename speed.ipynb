# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghunk/sugarcane/blob/main/speed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="y4uzPDgeB6rEDxdHhxsW")
project = rf.workspace("buddetection").project("np_mynp")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to np_mynp-2 in yolov8:: 100%|██████████| 6719/6719 [00:02<00:00, 2961.29it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model=YOLO('bestv10.pt')

# %%
model.val(data='data.yaml')
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2,695,196 parameters, 0 gradients, 8.2 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 23.0MB/s]
# val: Scanning /content/datasets/np_mynp-2/test/labels... 268 images, 1 backgrounds, 0 corrupt: 100%|██████████| 268/268 [00:00<00:00, 448.31it/s]
# val: New cache created: /content/datasets/np_mynp-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:06<00:00,  2.53it/s]
#                    all        268        347      0.793      0.817      0.869       0.61
#                    FIT        125        162      0.787      0.796      0.863      0.655
#                  UNFIT        163        185      0.799      0.838      0.875      0.566
# Speed: 2.3ms preprocess, 6.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
# ...

# %%
model=YOLO('last.pt')
model.val(data='data.yaml')
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv3-tiny summary (fused): 63 layers, 12,128,692 parameters, 0 gradients, 18.9 GFLOPs
# val: Scanning /content/datasets/np_mynp-2/test/labels.cache... 268 images, 1 backgrounds, 0 corrupt: 100%|██████████| 268/268 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:06<00:00,  2.69it/s]
#                    all        268        347      0.613      0.801      0.689      0.339
#                    FIT        125        162       0.58      0.802      0.678      0.372
#                  UNFIT        163        185      0.646      0.799      0.699      0.305
# Speed: 1.0ms preprocess, 6.2ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# ...

# %%
model=YOLO('customv8.pt')
model.val(data='data.yaml')
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# myconf summary (fused): 168 layers, 1,994,774 parameters, 0 gradients, 5.6 GFLOPs
# val: Scanning /content/datasets/np_mynp-2/test/labels.cache... 268 images, 1 backgrounds, 0 corrupt: 100%|██████████| 268/268 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:04<00:00,  3.58it/s]
#                    all        268        347      0.895      0.859      0.918      0.634
#                    FIT        125        162      0.888      0.833      0.914      0.682
#                  UNFIT        163        185      0.901      0.885      0.922      0.585
# Speed: 1.5ms preprocess, 4.8ms inference, 0.1ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/val4
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
print(1000/4.789)
# Out:
# 208.8118605136772

# %%
model=YOLO('bestv9.pt')
model.val(data='data.yaml')
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv9t summary (fused): 486 layers, 1,971,174 parameters, 0 gradients, 7.6 GFLOPs
# val: Scanning /content/datasets/np_mynp-2/test/labels.cache... 268 images, 1 backgrounds, 0 corrupt: 100%|██████████| 268/268 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:05<00:00,  3.30it/s]
#                    all        268        347      0.895      0.868      0.936      0.669
#                    FIT        125        162      0.861      0.878      0.931      0.709
#                  UNFIT        163        185       0.93      0.858      0.941      0.628
# Speed: 0.9ms preprocess, 7.4ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val5
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
model=YOLO('bestv5.pt')
model.val(data='data.yaml')
#yolo predict model=yolov8n.pt
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5n summary (fused): 193 layers, 2,503,334 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /content/datasets/np_mynp-2/test/labels.cache... 268 images, 1 backgrounds, 0 corrupt: 100%|██████████| 268/268 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:07<00:00,  2.18it/s]
#                    all        268        347      0.861      0.863      0.915      0.626
#                    FIT        125        162      0.858      0.818      0.903      0.677
#                  UNFIT        163        185      0.864      0.908      0.928      0.575
# Speed: 3.5ms preprocess, 5.5ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/val6
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
from google.colab import files
import shutil

# Set the path to the folder you want to download
folder_path = '/content/runs'

# Create a zip file of the folder
shutil.make_archive('/content/runsv10_download', 'zip', folder_path)

# Download the zip file
files.download('/content/runsv10_download.zip')

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestv8.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.4/78.2 GB disk)
#
# Benchmarks complete for bestv8.pt on data.yaml at imgsz=640 (587.61s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0               0.6310                   12.08   82.77
# 1             TorchScript       ✅       11.9               0.6088                    5.44  183.88
# 2                    ONNX       ✅       11.7               0.6088                  173.58    5.76
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       15.0               0.6088                    5.40  185.15
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       29.2               0.6088                   16.76   59.66
# ...
