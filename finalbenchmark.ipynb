# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghunk/sugarcane/blob/main/finalbenchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.9/112.6 GB disk)

# %%
# !nvidia-smi
# Out:
# Mon Apr  7 03:59:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             11W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="y4uzPDgeB6rEDxdHhxsW")
project = rf.workspace("buddetection").project("np_mynp")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 118.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to np_mynp-5 in yolov8:: 100%|██████████| 5622/5622 [00:01<00:00, 4942.46it/s]

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="best_our.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for best_our.pt on data.yaml at imgsz=640 (265.39s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.6              0.6371                  18.25   54.79
# 1             TorchScript       ✅        9.1              0.6168                   9.57  104.51
# 2                    ONNX       ✅        8.7              0.6168                    7.5  133.35
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅       13.6              0.6168                   4.59  217.74
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestv9.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for bestv9.pt on data.yaml at imgsz=640 (322.61s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4              0.6439                   26.4   37.88
# 1             TorchScript       ✅        8.6              0.6152                  14.03   71.29
# 2                    ONNX       ✅        7.9              0.6152                  60.66   16.49
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅       13.9              0.6152                   4.56  219.14
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
benchmark(model="/content/bestv11.pt", data="data.yaml", imgsz=640, half=False, format="torchscript")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.8/112.6 GB disk)
#
# Benchmarks complete for /content/bestv11.pt on data.yaml at imgsz=640 (57.62s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  TorchScript       ✅       10.4                0.602                  161.98  6.17
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  TorchScript       ✅       10.4                0.602                  161.98  6.17

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="best_v8.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 49.9/112.6 GB disk)
#
# Benchmarks complete for best_v8.pt on data.yaml at imgsz=640 (1063.91s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.6418                  12.12   82.47
# 1             TorchScript       ✅       11.9              0.6254                   6.66  150.18
# 2                    ONNX       ✅       11.7              0.6254                   7.23  138.24
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅       15.3              0.6254                   3.33  300.42
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...
