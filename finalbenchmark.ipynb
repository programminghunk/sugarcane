# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghunk/sugarcane/blob/main/finalbenchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.2.77 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
# !nvidia-smi
# Out:
# Wed Aug 14 02:51:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from IPython import display
display.clear_output()

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="y4uzPDgeB6rEDxdHhxsW")
project = rf.workspace("buddetection").project("np_mynp")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.77, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in np_mynp-2 to yolov8:: 100%|██████████| 251830/251830 [00:16<00:00, 15144.06it/s]
# Extracting Dataset Version Zip to np_mynp-2 in yolov8:: 100%|██████████| 6719/6719 [00:02<00:00, 3318.35it/s]

# %%
from ultralytics import YOLO
model = YOLO('bestfinal.pt')

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestfinal.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.0/78.2 GB disk)
#
# Benchmarks complete for bestfinal.pt on data.yaml at imgsz=640 (591.42s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.5               0.6503                   19.23   52.01
# 1             TorchScript       ✅        8.9               0.6141                    9.70  103.10
# 2                    ONNX       ✅        8.4               0.6141                  142.97    6.99
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.6               0.6141                    4.64  215.41
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       21.1               0.6141                   21.78   45.92
# 7     TensorFlow GraphDef       ✅        8.5               0.6141                   18.67   53.56
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.8               0.6141                  340.29    2.94
# 12                   NCNN       ✅        8.4               0.6141                  117.38    8.52
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.5               0.6503                   19.23   52.01
# 1             TorchScript       ✅        8.9               0.6141                    9.70  103.10
# 2                    ONNX       ✅        8.4               0.6141                  142.97    6.99
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.6               0.6141                    4.64  215.41
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       21.1               0.6141                   21.78   45.92
# 7     TensorFlow GraphDef       ✅        8.5               0.6141                   18.67   53.56
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.8               0.6141                  340.29    2.94
# 12                   NCNN       ✅        8.4               0.6141                  117.38    8.52
