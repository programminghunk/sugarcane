# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghunk/sugarcane/blob/main/finalbenchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 60776, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 60776 (delta 17), reused 7 (delta 5), pack-reused 60740 (from 3)
# Receiving objects: 100% (60776/60776), 32.89 MiB | 22.65 MiB/s, done.
# Resolving deltas: 100% (45205/45205), done.

# %%
# !nvidia-smi
# Out:
# Thu Jun  5 09:39:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd ultralytics
# !pip install -e '.[dev]'
# Out:
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 127.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="y4uzPDgeB6rEDxdHhxsW")
project = rf.workspace("buddetection").project("np_mynp")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to np_mynp-5 in yolov8:: 100%|██████████| 5622/5622 [00:01<00:00, 5578.14it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
from ultralytics import YOLO

model=YOLO('/content/bestv12.pt')
model.info()
# Out:
# conf summary: 209 layers, 1,520,398 parameters, 0 gradients, 4.6 GFLOPs
# (209, 1520398, 0, 4.626944)

# %%
# Benchmark on GPU
benchmark(model="/content/bestv12_our.pt", data="/content/ultralytics/np_mynp-5/data.yaml", imgsz=640, half=False, device=0)#3.26mb
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.6/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on /content/ultralytics/np_mynp-5/data.yaml at imgsz=640 (499.58s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        3.2              0.6257                  14.33   69.79
# 1             TorchScript       ✅        6.4              0.5973                   7.36  135.77
# 2                    ONNX       ✅        6.0              0.5973                   7.06  141.54
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅        9.1              0.5973                   3.73  268.01
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestv9.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for bestv9.pt on data.yaml at imgsz=640 (322.61s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4              0.6439                   26.4   37.88
# 1             TorchScript       ✅        8.6              0.6152                  14.03   71.29
# 2                    ONNX       ✅        7.9              0.6152                  60.66   16.49
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅       13.9              0.6152                   4.56  219.14
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
benchmark(model="/content/bestv11.pt", data="data.yaml", imgsz=640, half=False, format="torchscript")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.8/112.6 GB disk)
#
# Benchmarks complete for /content/bestv11.pt on data.yaml at imgsz=640 (57.62s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  TorchScript       ✅       10.4                0.602                  161.98  6.17
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  TorchScript       ✅       10.4                0.602                  161.98  6.17

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestv8.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 49.9/112.6 GB disk)
#
# Benchmarks complete for bestv8.pt on data.yaml at imgsz=640 (1148.25s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.6418                  12.03   83.14
# 1             TorchScript       ✅       11.9              0.6254                   6.68  149.75
# 2                    ONNX       ✅       11.7              0.6254                   6.88  145.41
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ✅       15.4              0.6254                   3.84  260.51
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/bestv12.pt", data="data.yaml", imgsz=640, format="onnx")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.6/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=640 (56.69s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0   ONNX       ✅       10.0               0.5573                  144.71  6.91
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0   ONNX       ✅       10.0               0.5573                  144.71  6.91

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/bestv12.pt", data="data.yaml", format="mnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.9/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (20.58s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.8               0.1815                   10.06  99.41
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.8               0.1815                   10.06  99.41

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/bestv12.pt", data="data.yaml", format="ncnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (31.96s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0   NCNN       ✅        9.8                  0.0                   62.51  16.0
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0   NCNN       ✅        9.8                  0.0                   62.51  16.0

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/best11.pt", data="data.yaml", format="ncnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.0/112.6 GB disk)
#
# Benchmarks complete for /content/best11.pt on data.yaml at imgsz=160 (7.31s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   NCNN       ✅        9.9               0.1726                    7.54  132.67
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   NCNN       ✅        9.9               0.1726                    7.54  132.67

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/best11.pt", data="data.yaml", format="mnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.0/112.6 GB disk)
#
# Benchmarks complete for /content/best11.pt on data.yaml at imgsz=160 (5.97s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.9               0.1726                    8.62  116.0
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.9               0.1726                    8.62  116.0

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/best11.pt", data="data.yaml", format="onnx")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.0/112.6 GB disk)
#
# Benchmarks complete for /content/best11.pt on data.yaml at imgsz=160 (6.24s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        9.9               0.1726                    8.77  114.01
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        9.9               0.1726                    8.77  114.01

# %%
from ultralytics.utils.benchmarks import benchmark

benchmark(model="/content/bestv10.pt", data="data.yaml", format="onnx")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv10.pt on data.yaml at imgsz=160 (7.66s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        8.7               0.1608                    7.49  133.55
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        8.7               0.1608                    7.49  133.55

# %%
benchmark(model="/content/bestv10.pt", data="data.yaml", format="ncnn",device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv10.pt on data.yaml at imgsz=160 (4.67s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im) FPS
# 0   NCNN       ❎        8.7                   -                      -   -
#   Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)   FPS
# 0   NCNN       ❎        8.7                None                   None  None

# %%
benchmark(model="/content/bestv10.pt", data="data.yaml", format="torchscript", device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv10.pt on data.yaml at imgsz=160 (9.29s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TorchScript       ✅       10.9               0.1608                    7.91  126.48
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TorchScript       ✅       10.9               0.1608                    7.91  126.48

# %%
benchmark(model="/content/bestv11.pt", data="data.yaml", format="torchscript", device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv11.pt on data.yaml at imgsz=160 (8.43s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TorchScript       ✅       10.3               0.1726                     8.2  121.95
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TorchScript       ✅       10.3               0.1726                     8.2  121.95

# %%
benchmark(model="/content/bestv11.pt", data="data.yaml", format="-")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv11.pt on data.yaml at imgsz=160 (9.56s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  PyTorch       ✅        5.2               0.2469                   24.43  40.94
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  PyTorch       ✅        5.2               0.2469                   24.43  40.94

# %%
benchmark(model="/content/bestv11.pt", data="data.yaml", format="onnx")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv11.pt on data.yaml at imgsz=160 (7.02s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0   ONNX       ✅        9.9               0.1726                    7.79  128.3
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0   ONNX       ✅        9.9               0.1726                    7.79  128.3

# %%
benchmark(model="/content/bestv12.pt", data="data.yaml", format="-",device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (8.93s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  PyTorch       ✅        5.3               0.1728                   21.31  46.93
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  PyTorch       ✅        5.3               0.1728                   21.31  46.93

# %%
benchmark(model="/content/bestv12.pt", data="data.yaml", format="onnx")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (7.86s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        9.9               0.1815                    9.44  105.93
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0   ONNX       ✅        9.9               0.1815                    9.44  105.93

# %%
benchmark(model="/content/bestv12.pt", data="data.yaml", format="torchscript", device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (12.16s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  TorchScript       ✅       10.4               0.1815                   13.96  71.61
#         Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  TorchScript       ✅       10.4               0.1815                   13.96  71.61

# %%
benchmark(model="/content/bestv12.pt", data="data.yaml", format="mnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.0/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (9.65s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.8               0.1815                   13.36  74.85
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0    MNN       ✅        9.8               0.1815                   13.36  74.85

# %%
benchmark(model="/content/bestv12.pt", data="data.yaml", format="ncnn")
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.1/112.6 GB disk)
#
# Benchmarks complete for /content/bestv12.pt on data.yaml at imgsz=160 (21.19s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0   NCNN       ✅        9.8                  0.0                    45.4  22.03
#   Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0   NCNN       ✅        9.8                  0.0                    45.4  22.03
