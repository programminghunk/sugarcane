# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghunk/sugarcane/blob/main/finalbenchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
# !nvidia-smi
# Out:
# Mon Aug 12 09:29:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from IPython import display
display.clear_output()

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="y4uzPDgeB6rEDxdHhxsW")
project = rf.workspace("buddetection").project("np_mynp")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.4 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.76, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in np_mynp-2 to yolov8:: 100%|██████████| 251830/251830 [00:05<00:00, 45225.80it/s]
# Extracting Dataset Version Zip to np_mynp-2 in yolov8:: 100%|██████████| 6719/6719 [00:04<00:00, 1411.72it/s]

# %%
from ultralytics import YOLO
model = YOLO('bestfinal.pt')

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestfinal.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.0/78.2 GB disk)
#
# Benchmarks complete for bestfinal.pt on data.yaml at imgsz=640 (598.44s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4               0.6454                   22.37   44.69
# 1             TorchScript       ✅        8.8               0.6320                   11.64   85.91
# 2                    ONNX       ✅        8.3               0.6320                  142.64    7.01
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.4               0.6320                    4.51  221.65
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       20.8               0.6320                   20.64   48.45
# 7     TensorFlow GraphDef       ✅        8.4               0.6320                   21.44   46.65
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.6               0.6320                  332.53    3.01
# 12                   NCNN       ✅        8.2               0.6320                   95.92   10.42
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4               0.6454                   22.37   44.69
# 1             TorchScript       ✅        8.8               0.6320                   11.64   85.91
# 2                    ONNX       ✅        8.3               0.6320                  142.64    7.01
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.4               0.6320                    4.51  221.65
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       20.8               0.6320                   20.64   48.45
# 7     TensorFlow GraphDef       ✅        8.4               0.6320                   21.44   46.65
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.6               0.6320                  332.53    3.01
# 12                   NCNN       ✅        8.2               0.6320                   95.92   10.42

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model="bestfinal.pt", data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.0/78.2 GB disk)
#
# Benchmarks complete for bestfinal.pt on data.yaml at imgsz=640 (388.48s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4               0.6454                   23.17   43.15
# 1             TorchScript       ✅        8.8               0.6320                   12.47   80.18
# 2                    ONNX       ✅        8.3               0.6320                  144.36    6.93
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.6               0.6320                    4.76  209.89
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       20.8               0.6320                   23.96   41.73
# 7     TensorFlow GraphDef       ✅        8.4               0.6320                   20.76   48.16
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.6               0.6320                  334.46    2.99
# 12                   NCNN       ✅        8.2               0.6320                   95.34   10.49
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        4.4               0.6454                   23.17   43.15
# 1             TorchScript       ✅        8.8               0.6320                   12.47   80.18
# 2                    ONNX       ✅        8.3               0.6320                  144.36    6.93
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ✅       12.6               0.6320                    4.76  209.89
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ✅       20.8               0.6320                   23.96   41.73
# 7     TensorFlow GraphDef       ✅        8.4               0.6320                   20.76   48.16
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN     NaN
# 11           PaddlePaddle       ✅       16.6               0.6320                  334.46    2.99
# 12                   NCNN       ✅        8.2               0.6320                   95.34   10.49
